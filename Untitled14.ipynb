# %% [markdown]
# <a href="https://colab.research.google.com/github/alhakimia542-ctrl/-/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# سيطلب منك هذا الكود الإذن للوصول إلى ملفاتك في درايف
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# عرض الملفات الموجودة في المجلد الرئيسي للدرايف للتأكد من المسارات
print("الملفات الموجودة في Google Drive:")
# !ls "/content/drive/MyDrive/"
# Out:
# الملفات الموجودة في Google Drive:
#  Arabic_Project		      kidney_processed
# 'Augmented Dataset.rar'       label_encoder.joblib
#  BERT_Arabic_model_fp16      'Original Dataset.rar'
#  BERT_Arabic_model_test       UltimateArabic.csv
#  BERT_Arabic_tokenizer_fp16   UltimateArabic_embeddings.npy
#  BERT_Arabic_tokenizer_test   UltimateArabicPrePos.rar
# 'Colab Notebooks'	      UltimateArabic.rar
#  datasetmp_zipped.zip	      Ultimate_Extracted
#  dental_best_model.pt	      Ultimate_Work_Space
#  kidney_model.pth	     'مجلد بلا عنوان'
#  kidney_model_script.pt

# %%
# !sudo apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
import os

def find_rar_files(search_path):
    print("🔎 جارٍ البحث عن ملفات RAR في الدرايف...")
    found = False
    for root, dirs, files in os.walk(search_path):
        for file in files:
            if file.lower().endswith(".rar"):
                print(f"✅ وجدته: {os.path.join(root, file)}")
                found = True
    if not found:
        print("❌ لم أجد أي ملف RAR. تأكد من رفعه أو من ربط الدرايف.")

find_rar_files('/content/drive/MyDrive')
# Out:
# 🔎 جارٍ البحث عن ملفات RAR في الدرايف...
# ❌ لم أجد أي ملف RAR. تأكد من رفعه أو من ربط الدرايف.

# %%
import os
from google.colab import drive

# إعادة التأكيد على الربط
drive.mount('/content/drive', force_remount=True)

print("\n🔍 قائمة بأول 20 ملفاً في الدرايف الخاص بك:")
print("-" * 30)
try:
    files = os.listdir('/content/drive/MyDrive')
    for f in files[:20]:
        print(f"📄 {f}")
except Exception as e:
    print(f"❌ خطأ في الوصول: {e}")
# Out:
# Mounted at /content/drive
#
# 🔍 قائمة بأول 20 ملفاً في الدرايف الخاص بك:
# ------------------------------
# 📄 UltimateArabic.csv
# 📄 Colab Notebooks
# 📄 مجلد بلا عنوان
# 📄 kidney_processed
# 📄 kidney_model.pth
# 📄 kidney_model_script.pt
# 📄 datasetmp_zipped.zip
# 📄 UltimateArabic.rar
# 📄 UltimateArabic_embeddings.npy
# 📄 BERT_Arabic_model_test
# 📄 BERT_Arabic_tokenizer_test
# 📄 BERT_Arabic_model_fp16
# 📄 BERT_Arabic_tokenizer_fp16
# 📄 label_encoder.joblib
# 📄 UltimateArabicPrePos.rar
# 📄 Ultimate_Extracted
# 📄 Ultimate_Work_Space
# 📄 Arabic_Project
# 📄 Original Dataset.rar
# 📄 dental_best_model.pt

# %%
# استبدل المسار أدناه بالمسار الذي ظهر لك في الخطوة السابقة
path_to_rar = "المسار_الذي_نسخته_هنا"

# !mkdir -p /content/dental_data_final
# !unrar x "{path_to_rar}" /content/dental_data_final/
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
# Cannot open المسار_الذي_نسخته_هنا.rar
# No such file or directory
# No files to extract

# %%
# 1. تثبيت أداة فك ضغط RAR
# !sudo apt-get install unrar

# 2. إنشاء مجلدات للبيانات
# !mkdir -p /content/dental_data/augmented
# !mkdir -p /content/dental_data/original

# 3. فك ضغط الملفات (تأكد من تعديل الأسماء لتطابق ملفاتك في الدرايف)
# !unrar x "/content/drive/MyDrive/Augmented Dataset.rar" /content/dental_data/augmented/
# !unrar x "/content/drive/MyDrive/Original Dataset.rar" /content/dental_data/original/

print("✅ تمت عملية فك الضغط بنجاح!")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/Augmented Dataset.rar
#
# Creating    /content/dental_data/augmented/Augmented Dataset          OK
# Creating    /content/dental_data/augmented/Augmented Dataset/test     OK
# Creating    /content/dental_data/augmented/Augmented Dataset/test/images  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/dental_data/augmented/Augmented Dataset/test/labels  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
import os

# المسار بعد فك الضغط (تأكد من المسار الذي فككت فيه الضغط)
train_images_path = '/content/dental_data/augmented/train/images'
train_labels_path = '/content/dental_data/augmented/train/labels'

if os.path.exists(train_images_path) and os.path.exists(train_labels_path):
    num_images = len([f for f in os.listdir(train_images_path) if f.endswith(('.jpg', '.png'))])
    num_labels = len([f for f in os.listdir(train_labels_path) if f.endswith('.txt')])

    print(f"✅ عدد الصور: {num_images}")
    print(f"✅ عدد ملفات النصوص: {num_labels}")

    if num_images == num_labels:
        print("🚀 البيانات جاهزة تماماً ومثالية للبدء!")
    else:
        print("⚠️ تحذير: هناك اختلاف بين عدد الصور والنصوص، قد نحتاج لتنظيف البيانات.")
else:
    print("❌ المسار غير موجود، تأكد من فك الضغط في المكان الصحيح.")
# Out:
# ❌ المسار غير موجود، تأكد من فك الضغط في المكان الصحيح.

# %%
# 1. تثبيت unrar
# !sudo apt-get install unrar -y

# 2. إنشاء المجلدات
# !mkdir -p /content/dataset/augmented
# !mkdir -p /content/dataset/original

# 3. فك ضغط Augmented (المسار الجديد الذي ظهر في الصورة)
# !unrar x "/content/drive/MyDrive/Augmented Dataset.rar" /content/dataset/augmented/

# 4. فك ضغط Original
# !unrar x "/content/drive/MyDrive/Original Dataset.rar" /content/dataset/original/

print("✅ تمت العملية! الصور الآن خارج السجن المضغوط.")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/Augmented Dataset.rar
#
# Creating    /content/dataset/augmented/Augmented Dataset              OK
# Creating    /content/dataset/augmented/Augmented Dataset/test         OK
# Creating    /content/dataset/augmented/Augmented Dataset/test/images  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/dataset/augmented/Augmented Dataset/test/labels  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
import yaml

# المسارات بعد فك الضغط (تأكد من مطابقة أسماء المجلدات)
data_config = {
    'train': '/content/dataset/augmented/train/images',
    'val': '/content/dataset/augmented/valid/images',
    'test': '/content/dataset/augmented/test/images',
    'nc': 6,  # عدد الأصناف (Classes) بناءً على ما رأيناه في صورك
    'names': ['BDC-BDR', 'Caries', 'Fractured Teeth', 'Healthy Teeth', 'Impacted teeth', 'Infection']
}

with open('/content/dataset/augmented/data.yaml', 'w') as f:
    yaml.dump(data_config, f)

print("✅ تم إنشاء ملف data.yaml بنجاح!")
# Out:
# ✅ تم إنشاء ملف data.yaml بنجاح!

# %%
import os
import matplotlib.pyplot as plt
import cv2
import glob

# البحث عن أول صورة بصيغة jpg في مجلد التدريب
train_path = '/content/dataset/augmented/train/images/'
image_files = glob.glob(train_path + "*.jpg")

if image_files:
    sample_path = image_files[0] # أخذ أول صورة موجودة
    print(f"✅ تم العثور على الصورة: {sample_path}")

    img = cv2.imread(sample_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(10, 10))
    plt.imshow(img_rgb)
    plt.title(f"Sample: {os.path.basename(sample_path)} (After Enhancement)")
    plt.axis('off')
    plt.show()
else:
    print("❌ لم يتم العثور على أي صور في المسار المحدد.")
    print("لنتحقق من المجلدات الموجودة فعلياً:")
    # !ls -R /content/dataset/augmented/ | head -n 20
# Out:
# ❌ لم يتم العثور على أي صور في المسار المحدد.
# لنتحقق من المجلدات الموجودة فعلياً:
# /content/dataset/augmented/:
# Augmented Dataset
# data.yaml
#
# /content/dataset/augmented/Augmented Dataset:
# test
# train
# valid
#
# /content/dataset/augmented/Augmented Dataset/test:
# images
# labels
#
# /content/dataset/augmented/Augmented Dataset/test/images:
# 104_jpg.rf.05501644f89b63b3f9ba38f2c2436c75.jpg
# 106_jpg.rf.55f75c16fffc0fea03b260bf91b8fc68.jpg
# 127_jpg.rf.c6c7a6eea86965354399e338b71fbc6a.jpg
# 143_jpg.rf.d7f7764bed646dc8d58806a732ef86f4.jpg
# 146_jpg.rf.416fe5cb77bd045aedfc942be5392ff6.jpg
# 150_jpg.rf.608ff673ae4ff875b58580c08f0ae389.jpg

# %%
import matplotlib.pyplot as plt
import cv2
import os

# المسار الصحيح المكتشف
real_sample_path = '/content/dataset/augmented/Augmented Dataset/test/images/104_jpg.rf.05501644f89b63b3f9ba38f2c2436c75.jpg'

if os.path.exists(real_sample_path):
    img = cv2.imread(real_sample_path)
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title("Sample Image Found!")
    plt.axis('off')
    plt.show()
else:
    print("❌ لا يزال هناك خطأ في المسار، لكننا سنعالجه في الخطوة التالية.")

# %%
import yaml

# المسارات الحقيقية بناءً على مخرجاتك
data_config = {
    'train': '/content/dataset/augmented/Augmented Dataset/train/images',
    'val': '/content/dataset/augmented/Augmented Dataset/valid/images',
    'test': '/content/dataset/augmented/Augmented Dataset/test/images',
    'nc': 6,
    'names': ['BDC-BDR', 'Caries', 'Fractured Teeth', 'Healthy Teeth', 'Impacted teeth', 'Infection']
}

# حفظ الملف في مكان يسهل الوصول إليه
with open('/content/dataset/data.yaml', 'w') as f:
    yaml.dump(data_config, f)

print("✅ تم تحديث ملف data.yaml بالمسارات الصحيحة!")
# Out:
# ✅ تم تحديث ملف data.yaml بالمسارات الصحيحة!

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# تحميل الموديل
model = YOLO('yolov8s.pt')

# بدء التدريب
results = model.train(
    data='/content/dataset/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='dental_opg_augmented'
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import shutil
import os

# إنشاء مجلد المشروع في الدرايف
drive_path = '/content/drive/MyDrive/Dental_OPG_Project'
os.makedirs(drive_path, exist_ok=True)

# مسار النموذج الأفضل (best.pt)
source_model = '/content/runs/detect/dental_opg_augmented/weights/best.pt'
destination_model = os.path.join(drive_path, 'best_dental_model.pt')

# نسخ الموديل
try:
    shutil.copy(source_model, destination_model)
    print(f"✅ تم الحفظ بنجاح! موديلك الآن آمن في الدرايف هنا: {destination_model}")
except:
    print("❌ حدث خطأ، تأكد من ربط الدرايف جيداً.")
# Out:
# ✅ تم الحفظ بنجاح! موديلك الآن آمن في الدرايف هنا: /content/drive/MyDrive/Dental_OPG_Project/best_dental_model.pt

# %%
import glob
import random
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# 1. تحميل الموديل
model = YOLO('/content/runs/detect/dental_opg_augmented/weights/best.pt')

# 2. جلب قائمة بصور الاختبار
test_images = glob.glob('/content/dataset/augmented/Augmented Dataset/test/images/*.jpg')

if test_images:
    # اختيار صورة عشوائية
    random_image = random.choice(test_images)
    print(f"📷 يتم الآن فحص الصورة: {random_image}")

    # 3. التنبؤ
    results = model.predict(source=random_image, conf=0.4)

    # 4. عرض النتيجة
    res_plotted = results[0].plot()
    cv2_imshow(res_plotted)
else:
    print("❌ لم أجد صوراً في مجلد الاختبار، تأكد من المسار.")
# Out:
# 📷 يتم الآن فحص الصورة: /content/dataset/augmented/Augmented Dataset/test/images/146_jpg.rf.416fe5cb77bd045aedfc942be5392ff6.jpg
#
# image 1/1 /content/dataset/augmented/Augmented Dataset/test/images/146_jpg.rf.416fe5cb77bd045aedfc942be5392ff6.jpg: 320x640 3 BDC-BDRs, 1 Infection, 11.2ms
# Speed: 0.9ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=640x301>

# %%
import shutil
import os

# 1. تحديد المسار في جوجل درايف (سننشئ مجلد اسمه Dental_Project)
destination_folder = '/content/drive/MyDrive/Dental_Project_Results'
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# 2. تحديد مسار الملف الناتج من التدريب (تأكد من اسم المجلد dental_opg_augmented)
source_path = '/content/runs/detect/dental_opg_augmented/weights/best.pt'

# 3. اسم الملف الجديد في الدرايف
destination_path = os.path.join(destination_folder, 'my_dental_yolo_model.pt')

# 4. عملية النسخ
try:
    shutil.copy(source_path, destination_path)
    print(f"✅ تم حفظ النموذج بنجاح في الدرايف!")
    print(f"📍 المسار: {destination_path}")
except FileNotFoundError:
    print("❌ خطأ: لم يتم العثور على ملف النموذج. تأكد من اكتمال التدريب ومن اسم المجلد.")
# Out:
# ✅ تم حفظ النموذج بنجاح في الدرايف!
# 📍 المسار: /content/drive/MyDrive/Dental_Project_Results/my_dental_yolo_model.pt
